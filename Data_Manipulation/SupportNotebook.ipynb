# %%
import numpy as np
import pandas as pd

# %%
py_l = [i for i in range(100000)]

# %%
# %%timeit
py_ls = [i*2 for i in py_l]
# Out:
# 7.96 ms ± 2.3 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Convert to numpy array
py_a= np.array(py_l)

# %%
type(py_a)
# Out:
# numpy.ndarray

# %%
# %%timeit
py_ar = py_a*2
# Out:
# 85.6 µs ± 16.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
np_r=np.arange(100000)

# %%
np.ones((3)).ndim
# Out:
# 1

# %%
np.ones((3,3)).ndim
# Out:
# 2

# %%
np.ones((3,3,3)).ndim
# Out:
# 3

# %%
# Generate 5*5 data frame containing random numbers where index values [1,2,3,4,5] and column names [a, b, c, d, e]

# %%
# Steps
# 1. np.random.rand(5,5) -> numpy array
# 2. Convert to dataframe
# 3. Assign column names
# 4. Assign row numbers

# %%
df = pd.DataFrame(np.random.rand(5,5), columns=['a','b','c','d','e'], index = [1,2,3,4,5])

# %%
df
# Out:
#           a         b         c         d         e
# 1  0.991279  0.397795  0.878764  0.230759  0.887062
# 2  0.802386  0.200859  0.674768  0.376670  0.771857
# 3  0.676977  0.023366  0.310064  0.195702  0.371045
# 4  0.047115  0.507621  0.794560  0.640706  0.620204
# 5  0.266102  0.854127  0.075872  0.764272  0.423661

# %%
# First two rows
df.head(2)
# Out:
#           a         b         c         d         e
# 1  0.991279  0.397795  0.878764  0.230759  0.887062
# 2  0.802386  0.200859  0.674768  0.376670  0.771857

# %%
df[:2]
# Out:
#           a         b         c         d         e
# 1  0.991279  0.397795  0.878764  0.230759  0.887062
# 2  0.802386  0.200859  0.674768  0.376670  0.771857

# %%
df.loc[1:2]
# Out:
#           a         b         c         d         e
# 1  0.991279  0.397795  0.878764  0.230759  0.887062
# 2  0.802386  0.200859  0.674768  0.376670  0.771857

# %%
df.iloc[0:2]
# Out:
#           a         b         c         d         e
# 1  0.991279  0.397795  0.878764  0.230759  0.887062
# 2  0.802386  0.200859  0.674768  0.376670  0.771857

# %%
# Last 2 rows
df.tail(2)
# Out:
#           a         b         c         d         e
# 4  0.047115  0.507621  0.794560  0.640706  0.620204
# 5  0.266102  0.854127  0.075872  0.764272  0.423661

# %%
df[-2:]
# Out:
#           a         b         c         d         e
# 4  0.047115  0.507621  0.794560  0.640706  0.620204
# 5  0.266102  0.854127  0.075872  0.764272  0.423661

# %%
# Shape
df.shape # (rows and cols)
# Out:
# (5, 5)

# %%
# Type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       5 non-null      float64
#  1   b       5 non-null      float64
#  2   c       5 non-null      float64
#  3   d       5 non-null      float64
#  4   e       5 non-null      float64
# dtypes: float64(5)
# memory usage: 412.0 bytes

# %%
df.dtypes
# Out:
# a    float64
# b    float64
# c    float64
# d    float64
# e    float64
# dtype: object

# %%
# Stat summary of dataframe
df.describe()
# Out:
#               a         b         c         d         e
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.556772  0.396754  0.546806  0.441622  0.614766
# std    0.389811  0.315941  0.341239  0.251444  0.220666
# min    0.047115  0.023366  0.075872  0.195702  0.371045
# 25%    0.266102  0.200859  0.310064  0.230759  0.423661
# 50%    0.676977  0.397795  0.674768  0.376670  0.620204
# 75%    0.802386  0.507621  0.794560  0.640706  0.771857
# max    0.991279  0.854127  0.878764  0.764272  0.887062

# %%
# Drop column ‘e’
df.drop('e', axis=1, inplace=True)

# %%
df
# Out:
#           a         b         c         d
# 1  0.991279  0.397795  0.878764  0.230759
# 2  0.802386  0.200859  0.674768  0.376670
# 3  0.676977  0.023366  0.310064  0.195702
# 4  0.047115  0.507621  0.794560  0.640706
# 5  0.266102  0.854127  0.075872  0.764272

# %%
# Add column f as sum of b and c col
df['f'] = df['b']+df['c']
df
# Out:
#           a         b         c         d         f
# 1  0.991279  0.397795  0.878764  0.230759  1.276560
# 2  0.802386  0.200859  0.674768  0.376670  0.875627
# 3  0.676977  0.023366  0.310064  0.195702  0.333431
# 4  0.047115  0.507621  0.794560  0.640706  1.302181
# 5  0.266102  0.854127  0.075872  0.764272  0.930000

# %%
# Sum of all rows of col a
df['a'].sum()
# Out:
# 2.78385873117825

# %%
df.loc[1].sum()
# Out:
# 3.775156577102658

# %%
# Filter values > 0.5
df>0.5
# Out:
#        a      b      c      d      f
# 1   True  False   True  False   True
# 2   True  False   True  False   True
# 3   True  False  False  False  False
# 4  False   True   True   True   True
# 5  False   True  False   True   True

# %%
# Get values > 0.5
df[df>0.5]
# Out:
#           a         b         c         d         f
# 1  0.991279       NaN  0.878764       NaN  1.276560
# 2  0.802386       NaN  0.674768       NaN  0.875627
# 3  0.676977       NaN       NaN       NaN       NaN
# 4       NaN  0.507621  0.794560  0.640706  1.302181
# 5       NaN  0.854127       NaN  0.764272  0.930000

# %%
# Get values > 0.5  for col c and d
df[df>0.5][['c','d']]
# Out:
#           c         d
# 1  0.878764       NaN
# 2  0.674768       NaN
# 3       NaN       NaN
# 4  0.794560  0.640706
# 5       NaN  0.764272

# %%
df
# Out:
#           a         b         c         d         f
# 1  0.991279  0.397795  0.878764  0.230759  1.276560
# 2  0.802386  0.200859  0.674768  0.376670  0.875627
# 3  0.676977  0.023366  0.310064  0.195702  0.333431
# 4  0.047115  0.507621  0.794560  0.640706  1.302181
# 5  0.266102  0.854127  0.075872  0.764272  0.930000

# %%
a =pd.Series(df['a'])

# %%
a
# Out:
# 1    0.991279
# 2    0.802386
# 3    0.676977
# 4    0.047115
# 5    0.266102
# Name: a, dtype: float64

# %%
a.index = [6,7,8,9,19]
a
# Out:
# 6     0.991279
# 7     0.802386
# 8     0.676977
# 9     0.047115
# 19    0.266102
# Name: a, dtype: float64
